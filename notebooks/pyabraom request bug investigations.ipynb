# %%
import pyabraom
import requests
import pandas as pd
import numpy as np

# %%
abr1 = pyabraom.Search_gene("hg38", "idua", Variant_ID=True)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...

# %%
url = "http://abraom.ib.usp.br/script.php"
version = "abraomdbgenoma"
query="idua"

# %%
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry


session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

response= session.post(url, data={"table":version,"str":query}, timeout=None)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...

# %%
response= requests.post(url, data={"table":version,"str":query}, timeout=None, verify=False)
# Out:
# /home/colombelli/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'abraom.ib.usp.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
response.json()
# Out:
# {'error': "An SQL error occurred: SQLSTATE[42000]: Syntax error or access violation: 1103 Incorrect table name ''"}

# %%
import time

response = None
while not response:
    try:
        response = requests.post(url, data={"table":version,"str":query}, timeout=None)
        break
    except:
        print("Connection refused by the server..")
        print("Let me sleep for 5 seconds")
        print("ZZzzzz...")
        time.sleep(5)
        print("Was a nice sleep, now let me continue...")
        continue
# Out:
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ...

# %%
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and
getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

response= requests.post(url, data={"table":version,"str":query}, timeout=None)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...

# %%
import ssl
context = ssl._create_unverified_context()

response= requests.post(url, data={"table":version,"str":query}, timeout=None)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...

# %%
import certifi

response= requests.post(url, data={"table":version,"str":query}, timeout=None)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...

# %%
import certifi
import ssl

response= requests.post(url, data={"table":version,"str":query}, timeout=None, context=ssl.create_default_context(cafile=certifi.where()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-6687f9d85726> in <module>
#       2 import ssl
#       3
# ----> 4 response= requests.post(url, data={"table":version,"str":query}, timeout=None, context=ssl.create_default_context(cafile=certifi.where()))
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~/.pyenv/versions/3.6.13/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# TypeError: request() got an unexpected keyword argument 'context'
