# %%
from pyabraom import *
from pynoma import *

# %%
rs = RegionSearch(3, 17, 43045690, 43045710)
df, clinical_df = rs.get_data()

# %%
reg = 89740838
df = Search_region('hg38', 16, reg-50, reg+50)

# %%
rs = GeneSearch(3, 'BAK1')
mad_df, clinical_df = rs.get_data()

# %%
df = Search_gene('hg38', 'BAK1')
dels = df.loc[df['Alternative'] == "-"].Position.values

# %%
mad_df.loc[mad_df.Location.isin(dels)]
# Out:
#     Variant ID      rsID         Gene  Consequence Annotation           Flags  \
# 283  6-33577640-G-T  rs375089143  BAK1  c.-31-5C>A  splice_region_va...  []
# 284  6-33577640-G-A  rs375089143  BAK1  c.-31-5C>T  splice_region_va...  []
#
#      Allele Count  Allele Number  Allele Frequency  Number of Homozygotes  \
# 283  1             151382         0.000007          0
# 284  3             151382         0.000020          0
#
#     Source  Chromosome Location  Reference Alternative
# 283  Genome  6          33577640  G         T
# 284  Genome  6          33577640  G         A

# %%
rs = GeneSearch(3, 'clu')
mad_df, clinical_df = rs.get_data()
mad_df.loc[mad_df.Annotation == "inframe_deletion"]
# Out:
#     Variant ID           rsID          Gene Consequence          \
# 95   8-27598614-AGTCA...   rs751418298  CLU  p.Thr393_Asp395del
# 342    8-27605093-AAAG-A   rs778445133  CLU         p.Phe220del
# 485    8-27608941-TTTC-T  rs1462955044  CLU          p.Lys81del
# 487    8-27608954-GCTT-G          None  CLU          p.Glu76del
#
#     Annotation        Flags  Allele Count  Allele Number  Allele Frequency  \
# 95   inframe_deletion  []     5            152228         0.000033
# 342  inframe_deletion  []    13            152024         0.000086
# 485  inframe_deletion  []     1            152252         0.000007
# 487  inframe_deletion  []     1            152172         0.000007
#
#      Number of Homozygotes Source  Chromosome Location  Reference    \
# 95   0                      Genome  8          27598614  AGTCAGAAGT
# 342  0                      Genome  8          27605093        AAAG
# 485  0                      Genome  8          27608941        TTTC
# 487  0                      Genome  8          27608954        GCTT
#
#     Alternative
# 95   A
# 342  A
# 485  T
# 487  G

# %%
reg = 27598614
df = Search_region('hg38', 8, reg-50, reg+50)

# %%
df
# Out:
#   Chromosome Position  Reference  Alternative Annotation           Gene  \
# 0  8          27598609          G  A                synonymous SNV  CLU
# 1  8          27598613          G  A             nonsynonymous SNV  CLU
# 2  8          27598615  GTCAGAAGT  -           nonframeshift de...  CLU
#
#   GATK Filter Number of Homozygotes Allele Number Allele Count  \
# 0  PASS        0                     2342           1
# 1  PASS        0                     2342          13
# 2  PASS        0                     2342           1
#
#   Allele Frequency
# 0  0.000427
# 1  0.005551
# 2  0.000427
